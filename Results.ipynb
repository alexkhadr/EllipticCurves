# %% [markdown]
# # Result Graphs

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Mod 3

# %%
List_65a2 = [168 / 84, 247 / 105, 292 / 131, 331 / 150, 361 / 169, 400 / 185, 417 / 202, 442 / 208, 466 / 221, 499 / 232, 528 / 247, 552 / 258, 579 / 265, 592 / 276, 613 / 285, 625 / 293]

# %%
List_83a1 = [252 / 115, 327 / 144, 388 / 179, 426 / 195, 468 / 219, 505 / 232, 545 / 252, 569 / 270, 596 / 295, 625 / 310, 649 / 321, 678 / 338, 705 / 352, 731 / 373, 745 / 386, 758 / 400]

# %%
List_53a1 = [226 / 116, 309 / 163, 363 / 190, 436 / 211, 476 / 239, 527 / 259, 560 / 276, 593 / 290, 625 / 312, 661 / 327, 685 / 341, 707 / 353, 723 / 371, 751 / 386, 769 / 402, 788 / 413]

# %%
List_21a1 = [352 / 185, 476 / 234, 574 / 273, 626 / 306, 711 / 337, 773 / 367, 830 / 399, 884 / 422, 923 / 449, 957 / 469, 1002 / 495, 1042 / 507, 1082 / 522, 1112 / 540, 1149 / 561, 1186 / 579]

# %%
List_38b2 = [301 / 136, 393 / 199, 465 / 233, 519 / 265, 566 / 287, 612 / 314, 646 / 341, 683 / 371, 725 / 397, 761 / 416, 801 / 432, 831 / 448, 864 / 466, 888 / 481, 905 / 501, 932 / 514]

# %%
List_55a1 = [373 / 176, 493 / 251, 583 / 300, 648 /332, 713 / 375, 771 / 423, 831 / 454, 883 / 482, 926 / 508, 962 / 527, 994 / 549, 1034 / 568, 1073 / 584, 1110 / 601, 1140 / 614, 1173 / 627]

# %%
List_X = [25_000_000, 50_000_000, 75_000_000, 100_000_000, 125_000_000, 150_000_000, 175_000_000, 200_000_000, 225_000_000, 250_000_000, 275_000_000, 300_000_000, 325_000_000, 350_000_000, 375_000_000, 400_000_000]

# %%
plt.plot(List_X, List_65a2, label = "line 65a2")
plt.plot(List_X, List_83a1, label = "line 83a1")
plt.plot(List_X, List_53a1, label = "line 53a2")
plt.plot(List_X, List_21a1, label = "line 21a1")
plt.plot(List_X, List_38b2, label = "line 38b2")
plt.plot(List_X, List_55a1, label = "line 55a1")
plt.legend()
plt.show()

# %%
plt.plot(List_X, List_65a2, label = "line 65a2")
plt.plot(List_X, List_83a1, label = "line 83a1")
plt.plot(List_X, List_53a1, label = "line 53a1")
plt.plot(List_X, List_21a1, label = "line 21a1")
plt.plot(List_X, List_38b2, label = "line 38b2")
plt.plot(List_X, List_55a1, label = "line 55a1")
plt.ylim(1, 3)

plt.legend()
plt.show()

# %%
plt.plot(List_X, List_65a2, label = "Curve 65.a2")
plt.plot(List_X, List_83a1, label = "Curve 83.a1")
plt.plot(List_X, List_53a1, label = "Curve 53.a1")
plt.plot(List_X, List_21a1, label = "Curve 21.a1")
plt.plot(List_X, List_38b2, label = "Curve 38.b2")
plt.plot(List_X, List_55a1, label = "Curve 55.a1")
plt.xlabel('Upper Bound on Primes')
plt.ylabel('Ratio')
plt.ylim(0, 4)

plt.legend()
plt.show()

# %% [markdown]
# ## Mod 5

# %%
List_65a2_5 = [72 / 47, 107 / 61, 128 / 77, 141 / 91, 155 / 105, 173 / 114, 187 / 118, 201 / 122, 213 / 127, 223 / 139, 236 / 149, 242 / 154, 249 / 161, 259 / 164, 265 / 173, 270 / 178]

# %%
List_83a1_5 = [113 / 77, 150 / 105, 174 / 121, 186 / 134, 214 / 155, 228 / 168, 251 / 174, 259 / 183, 271 / 192,  287 / 202, 298 / 207, 312 / 221, 327 / 230, 342 / 238, 347 / 242, 360 / 246]

# %%
List_53a1_5 = [99 / 63, 140 / 95, 163 / 106, 193 / 119, 213 / 136, 236 / 152, 251 / 166, 270 / 179, 286 / 190, 299 / 202, 313 / 210, 321 / 215, 330 / 223, 339 / 233, 355 / 236, 364 / 241]

# %%
List_21a1_5 = [147/115, 201/146, 246/173, 269/201, 297/220, 327/234, 350/254, 370/274, 385/290, 398/303, 416/321, 436/332, 455/348, 473/356, 488/367, 505/378]

# %%
List_55a1_5 = [171/102, 240/139, 269/165, 301/187, 332/207, 361/229, 389/249, 416/269, 435/282, 445/282, 468/298, 487/307, 509/316, 523/324, 535/334, 543/342]

# %%
plt.plot(List_X, List_65a2_5, label = "Curve 65.a2")
plt.plot(List_X, List_83a1_5, label = "Curve 83.a1")
plt.plot(List_X, List_53a1_5, label = "Curve 53.a1")
plt.plot(List_X, List_21a1_5, label = "Curve 21.a1")
plt.plot(List_X, List_55a1_5, label = "Curve 55.a1")
plt.xlabel('Upper Bound on Primes')
plt.ylabel('Ratio')
plt.ylim(1, 3)

plt.legend()
plt.show()

# %%
mod_1_count = [115, 144, 179, 195, 219, 232, 252, 270, 295, 310, 321, 338, 352, 373, 386, 400]
mod_2_count = [252, 327, 388, 426, 468, 505, 545, 569, 596, 625, 649, 678, 705, 731, 745, 758]

# %% [markdown]
# ## Mod 7

# %%
line_83a1_7 = [78 / 48, 99 / 68, 122 / 85, 138 / 94, 151 / 104, 158 / 109, 167 / 121, 179 / 127, 186 / 132, 193 / 140, 198 / 145, 207 / 147, 216 / 152, 221 / 159, 226 / 162, 231 / 164]
line_65a2_7 = [46 / 39, 63 / 50, 73 / 60, 91 / 69, 97 / 78, 104 / 93, 114 / 97, 122 / 100, 128 / 104, 137 / 109, 142 / 117, 152 / 121, 160 / 126, 165 / 128, 172 / 130, 176 / 133]
line_53a1_7 = [66 / 46, 91/58, 108/69, 125/89, 135/104, 146/115, 158/120, 166/127, 177/133, 189/138, 194/146, 202/148, 208/149, 215/152, 222/157, 226/163]

# %%
line_38b2_7 = [89/62, 114/90, 133/102, 149/113, 160/122, 177/132, 185/138, 197/145, 211/155, 220/165, 234/172, 238/182, 245/189, 247/198, 254/203, 259/207]

# %%
line_55a1_7 = [100/71, 133/89, 155/111, 180/128, 206/146, 226/155, 246/164, 258/173, 274/179, 286/189, 300/193, 311/205, 328/210, 337/217, 348/226, 355/231]

# %%
line_21a1_7 = [119/65, 167/86, 190/106, 205/120, 230/132, 249/145, 266/154, 287/166, 303/175, 312/182, 332/189, 338/201, 345/205, 353/211, 361/220, 366/224]

# %%
plt.plot(List_X, line_65a2_7, label = "Curve 65.a2")
plt.plot(List_X, line_83a1_7, label = "Curve 83.a1")
plt.plot(List_X, line_53a1_7, label = "Curve 53.a1")
plt.plot(List_X, line_21a1_7, label = "Curve 21.a1")
plt.plot(List_X, line_55a1_7, label = "Curve 55.a1")
plt.plot(List_X, line_38b2_7, label = "Curve 38.b2")
plt.xlabel('Upper Bound on Primes')
plt.ylabel('Ratio')
plt.ylim(1, 3)

plt.legend()
plt.show()

# %% [markdown]
# ## Growth Graphs

# %%
plt.plot(List_X, mod_1_count, label = "1 mod 3 count")
plt.plot(List_X, mod_2_count, label = "2 mod 3 count")

plt.xlabel('Upper Bound on Primes')
plt.ylabel('number of primes 2 mod 3 & 1 mod 3')
plt.ylim(0, 800)

plt.legend()
plt.show()

# %%
## 65.a2

# %%
mod_2 = [168, 247, 292, 331, 361, 400, 417, 442, 466, 499, 528, 552, 579, 592, 613, 625]
mod_1 = [84, 105, 131, 150, 169, 185, 202, 208, 221, 232, 247, 258, 265, 276, 285, 293]

# %%
plt.plot(List_X, mod_1, label = "1 mod 3 count")
plt.plot(List_X, mod_2, label = "2 mod 3 count")

plt.xlabel('Upper Bound on Primes')
plt.ylabel('number of primes 2 mod 3 & 1 mod 3')
plt.ylim(0, 800)

plt.legend()
plt.show()

# %%
## 53.a1

# %%
mo_1 = [99, 140, 163 , 193, 213 , 236, 251 , 270 , 286, 299, 313, 321 , 330 , 339, 355, 364]
mo_2 = [63,  95,  106, 119,  136, 152,  166,  179,  190, 202,  210, 215,  223,  233,  236,  241]

# %%
plt.plot(List_X, mo_1, label = "1 mod 5 count")
plt.plot(List_X, mo_2, label = "2 mod 5 count")

plt.xlabel('Upper Bound on Primes')
plt.ylabel('number of primes 2 mod 5 & 1 mod 5')
plt.ylim(0, 400)

plt.legend()
plt.show()

# %%
m_1 = [72, 107 , 128 , 141 , 155 , 173 , 187 , 201 , 213 , 223, 236 , 242 , 249 , 259 , 265 , 270 ]
m_2 = [ 47,  61,  77,  91,  105,  114,  118,  122, 127,  139,  149,  154, 161,  164,  173,  178]

# %%
plt.plot(List_X, m_1, label = "1 mod 5 count")
plt.plot(List_X, m_2, label = "2 mod 5 count")

plt.xlabel('Upper Bound on Primes')
plt.ylabel('number of primes 2 mod 5 & 1 mod 5')
plt.ylim(0, 400)

plt.legend()
plt.show()
